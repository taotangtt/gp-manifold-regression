# %%
import sys
import os

functions_path = os.path.abspath(os.path.join('..', 'functions'))
if functions_path not in sys.path:
    sys.path.append(functions_path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

# Import functions
from data import swiss_roll_curve, swiss_roll_response, simulated_data_loader
from methods import rescaled_gamma_prior_mcmc, knn_prior_mcmc, kernel_ridge_cv

# set the random seed 
np.random.seed(2026)

# %%
# visualize data and check value range
X, Y_de, Y = swiss_roll_curve(n_data = 20000, sigma_noise = 0.1, f= swiss_roll_response)

print("=== Data range per feature ===")
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)
for i, (min_val, max_val) in enumerate(zip(X_min, X_max)):
    print(f"Coordinate {i}: min = {min_val:.4f}, max = {max_val:.4f}")

X, Y_true, Y_noise = swiss_roll_curve(n_data = 2000, f = swiss_roll_response)
x = X[:,0]
y = X[:,1]
z_1 = X[:,2]
colo = Y_true

fig = plt.figure(figsize=(8, 3))
ax = plt.subplot(121, projection='3d')
color_map = pylab.cm.ScalarMappable()
color_map.set_array(colo)  
ax.scatter(x, y, z_1, marker='s', s=2, c= colo)
ax.set_box_aspect([1,1,1])
plt.subplot(122)
plt.hist(Y_true)
plt.show()
# Out:
# === Data range per feature ===
# Coordinate 0: min = 0.1335, max = 0.9202
# Coordinate 1: min = 0.0001, max = 1.0602
# Coordinate 2: min = 0.1320, max = 0.9712

# %%
# parameters for all baselines

data_loader_kwargs = dict(data_fn= swiss_roll_curve,f_fn= swiss_roll_response)
# data noise level
sigmasq_0 = 0.01

# grid_pos_param of marginal posterior of t
n_grid = 400
left_end = 0.0001 # 10 ** -6
right_end = 0.5
ls_grid_epsilon = np.linspace(left_end, right_end, n_grid)
grid_pos_tolerance = 10**(-10)

#MCMC params
mcmc_time = 3000
burn_in = 1000

# experiment runs
test_size = 2000

# to reproduce results in the paper, use the following setup
#replicas_ls =  [200,200,200,100,100,100]
#train_size_ls = [50,100,200,400,800,1600]

# reduced run times to demo
replicas_ls = [50, 50, 50]
train_size_ls = [50, 100, 200]

# %%
#rescaled gamma prior GP
d = 2
a_0 = 1
b_0 = 1 

w_pos_means = []
w_pos_std = []
w_pos_test_means = []
w_pos_test_std = []
dict_log_grid_pos = {}
dict_ls_epsilon = {}

for train_size, replicas in zip(train_size_ls, replicas_ls):
    n_data = train_size + test_size
    ls_w_pos,ls_w_pos_test,dict_log_grid_pos[train_size], dict_ls_epsilon[train_size] = \
                    rescaled_gamma_prior_mcmc(train_size, replicas, n_data, sigmasq_0,
                           n_grid,left_end,right_end, grid_pos_tolerance,
                           a_0, b_0, d, 
                           burn_in, mcmc_time,
                           data_loader=simulated_data_loader,data_loader_kwargs=data_loader_kwargs )
    w_pos_means.append(np.mean(ls_w_pos))
    w_pos_std.append(np.std(ls_w_pos))
    w_pos_test_means.append(np.mean(ls_w_pos_test))
    w_pos_test_std.append(np.std(ls_w_pos_test))
    print(f"train_size {train_size}, IS error {np.mean(ls_w_pos)}, OS error {np.mean(ls_w_pos_test)}")
# Out:
# 0 replica time: 1.26
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.14, err_os: 1.27
# 1 replica time: 1.16
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.09, err_os: 1.30
# 2 replica time: 1.20
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.90
# 3 replica time: 1.20
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.79
# 4 replica time: 1.22
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.39
# 5 replica time: 1.21
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.87
# 6 replica time: 1.18
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.09, err_os: 1.54
# 7 replica time: 1.17
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.88
# 8 replica time: 1.19
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.11, err_os: 2.28
# 9 replica time: 1.19
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.76
# 10 replica time: 1.17
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.81
# 11 replica time: 1.29
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.96
# 12 replica time: 1.24
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.22
# 13 replica time: 1.32
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.82
# 14 replica time: 1.20
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.10
# 15 replica time: 1.21
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.95
# 16 replica time: 1.20
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.09, err_os: 1.00
# 17 replica time: 1.09
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.10, err_os: 1.27
# 18 replica time: 1.23
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.59
# 19 replica time: 1.18
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.12, err_os: 1.38
# 20 replica time: 1.22
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.82
# 21 replica time: 1.18
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.09, err_os: 1.23
# 22 replica time: 1.14
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.98
# 23 replica time: 1.20
# proposal: 1.60e-03, start_point: 0.04, err_in: 0.11, err_os: 1.81
# 24 replica time: 1.20
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.12, err_os: 0.87
# 25 replica time: 1.12
# proposal: 1.15e-03, start_point: 0.03, err_in: 0.11, err_os: 1.85
# 26 replica time: 1.18
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.11, err_os: 1.50
# 27 replica time: 1.09
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.13, err_os: 1.09
# 28 replica time: 1.22
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.11, err_os: 1.20
# 29 replica time: 1.13
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.75
# 30 replica time: 1.32
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.12, err_os: 1.46
# 31 replica time: 1.23
# proposal: 1.15e-03, start_point: 0.04, err_in: 0.11, err_os: 0.98
# 32 replica time: 1.24
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.10, err_os: 1.10
# 33 replica time: 1.33
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.03
# 34 replica time: 1.34
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.13, err_os: 0.89
# 35 replica time: 1.30
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.97
# 36 replica time: 1.26
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.64
# 37 replica time: 1.26
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.13, err_os: 0.87
# 38 replica time: 1.24
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.12, err_os: 1.25
# 39 replica time: 1.29
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.27
# 40 replica time: 1.30
# proposal: 1.20e-03, start_point: 0.04, err_in: 0.11, err_os: 1.65
# 41 replica time: 1.22
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.13, err_os: 0.87
# 42 replica time: 1.27
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.13, err_os: 0.82
# 43 replica time: 1.24
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.09, err_os: 1.02
# 44 replica time: 1.24
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.11, err_os: 1.06
# 45 replica time: 1.28
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 1.02
# 46 replica time: 1.28
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.13, err_os: 0.69
# 47 replica time: 1.22
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.12, err_os: 1.13
# 48 replica time: 1.26
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.08, err_os: 1.54
# 49 replica time: 1.24
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.13, err_os: 0.90
# train_size 50, IS error 0.11099927649624569, OS error 1.106711046002509
# 0 replica time: 2.84
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.65
# 1 replica time: 2.92
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.86
# 2 replica time: 2.87
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.51
# 3 replica time: 3.09
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.10, err_os: 1.03
# 4 replica time: 2.84
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.47
# 5 replica time: 2.74
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.56
# 6 replica time: 3.15
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.43
# 7 replica time: 2.84
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.61
# 8 replica time: 2.90
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 1.61
# 9 replica time: 2.93
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.50
# 10 replica time: 2.83
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.56
# 11 replica time: 3.06
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.11, err_os: 0.46
# 12 replica time: 2.95
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.69
# 13 replica time: 3.03
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.41
# 14 replica time: 2.96
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.60
# 15 replica time: 2.86
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.60
# 16 replica time: 2.93
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.52
# 17 replica time: 2.81
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.50
# 18 replica time: 2.86
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.84
# 19 replica time: 2.94
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.44
# 20 replica time: 2.94
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.92
# 21 replica time: 3.03
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.60
# 22 replica time: 2.90
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.11, err_os: 0.44
# 23 replica time: 2.88
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.67
# 24 replica time: 2.90
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.52
# 25 replica time: 2.92
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.75
# 26 replica time: 2.91
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.55
# 27 replica time: 2.87
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.85
# 28 replica time: 2.92
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.53
# 29 replica time: 2.88
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.81
# 30 replica time: 2.96
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.56
# 31 replica time: 2.94
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.12, err_os: 0.52
# 32 replica time: 2.77
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.69
# 33 replica time: 2.91
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.44
# 34 replica time: 2.90
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.09, err_os: 0.61
# 35 replica time: 2.63
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.04
# 36 replica time: 2.93
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.81
# 37 replica time: 2.97
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.46
# 38 replica time: 3.10
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.63
# 39 replica time: 2.96
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.55
# 40 replica time: 2.86
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.11, err_os: 1.18
# 41 replica time: 2.83
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.42
# 42 replica time: 2.88
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.45
# 43 replica time: 2.87
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.72
# 44 replica time: 2.93
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.50
# 45 replica time: 3.04
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.88
# 46 replica time: 2.95
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.69
# 47 replica time: 2.94
# proposal: 5.51e-04, start_point: 0.02, err_in: 0.10, err_os: 0.42
# 48 replica time: 2.91
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.79
# 49 replica time: 3.00
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.51
# train_size 100, IS error 0.10216090506533676, OS error 0.6470606368130198
# 0 replica time: 6.62
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.23
# 1 replica time: 6.61
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 2 replica time: 6.67
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 3 replica time: 6.63
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.41
# 4 replica time: 6.68
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.28
# 5 replica time: 6.66
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.22
# 6 replica time: 6.60
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.32
# 7 replica time: 6.69
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.24
# 8 replica time: 6.88
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.24
# 9 replica time: 6.63
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.25
# 10 replica time: 6.62
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.20
# 11 replica time: 6.72
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.31
# 12 replica time: 6.74
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.30
# 13 replica time: 6.83
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.23
# 14 replica time: 6.68
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.07, err_os: 0.23
# 15 replica time: 6.76
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.26
# 16 replica time: 6.63
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 17 replica time: 6.77
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.24
# 18 replica time: 6.84
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.22
# 19 replica time: 6.83
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.39
# 20 replica time: 6.67
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.25
# 21 replica time: 6.75
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.32
# 22 replica time: 6.82
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.26
# 23 replica time: 6.70
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.30
# 24 replica time: 6.84
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.27
# 25 replica time: 6.82
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.21
# 26 replica time: 6.91
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.23
# 27 replica time: 6.79
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.28
# 28 replica time: 6.86
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.31
# 29 replica time: 6.94
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.32
# 30 replica time: 6.81
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 31 replica time: 6.82
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.30
# 32 replica time: 7.03
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.27
# 33 replica time: 6.94
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.35
# 34 replica time: 6.96
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.33
# 35 replica time: 6.93
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 36 replica time: 7.13
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.22
# 37 replica time: 7.01
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.34
# 38 replica time: 7.08
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.34
# 39 replica time: 7.05
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.19
# 40 replica time: 6.96
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.25
# 41 replica time: 7.08
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.20
# 42 replica time: 7.05
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.35
# 43 replica time: 7.10
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.07, err_os: 0.25
# 44 replica time: 7.06
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.31
# 45 replica time: 7.07
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.21
# 46 replica time: 7.09
# proposal: 4.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.21
# 47 replica time: 6.60
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.38
# 48 replica time: 6.66
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.24
# 49 replica time: 6.69
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.32
# train_size 200, IS error 0.08640684891578004, OS error 0.27567322637940705

# %%
# sanity check of the computed posterior of the reverse gamma prior
train_size = 50
# grid of marginal posterior of t
log_grid_pos = dict_log_grid_pos[train_size]
weight_pos = np.exp(log_grid_pos - np.max(log_grid_pos))
weight_pos = weight_pos/np.sum(weight_pos)

plt.figure(figsize=(8,3))
plt.subplot(121)
plt.plot(ls_grid_epsilon,weight_pos*(mcmc_time-burn_in),label = 'grid')
plt.title(f"train size {train_size}, grid vs mcmc")
plt.hist(dict_ls_epsilon[train_size][burn_in:],bins = ls_grid_epsilon)
plt.legend()
plt.subplot(122)
plt.plot(dict_ls_epsilon[train_size][burn_in:])
plt.title(f"train size {train_size}, mixing")
plt.show()

# %%
# knn prior GP
gamma1 = 0.25
gamma2 = 0.25
a_0 = 1
b_0 = 1

w_pos_knn_means = []
w_pos_knn_std = []
w_pos_knn_test_means = []
w_pos_knn_test_std = []
dict_Tn_count = {}
dict_log_grid_pos_knn = {}
dict_ls_epsilon_knn = {}

for train_size, replicas in zip(train_size_ls, replicas_ls):
    n_data = train_size + test_size
    ls_w_pos_knn,ls_w_pos_knn_test, dict_Tn_count[train_size], dict_log_grid_pos_knn[train_size], dict_ls_epsilon_knn[train_size] \
     = knn_prior_mcmc(train_size, replicas, n_data,sigmasq_0,
                      n_grid, left_end,right_end,grid_pos_tolerance,
                      a_0,b_0, gamma1, gamma2, 
                      burn_in, mcmc_time,
                      data_loader=simulated_data_loader,data_loader_kwargs=data_loader_kwargs,
                      v_hat_method='harmonic')
    w_pos_knn_means.append(np.mean(ls_w_pos_knn))
    w_pos_knn_std.append(np.std(ls_w_pos_knn))
    w_pos_knn_test_means.append(np.mean(ls_w_pos_knn_test))
    w_pos_knn_test_std.append(np.std(ls_w_pos_knn_test))
    print(f"train_size {train_size}, IS error {np.mean(ls_w_pos_knn)}, OS error {np.mean(ls_w_pos_knn_test)}")
# Out:
# 0 replica time: 1.42, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.09, err_os: 0.81
# 1 replica time: 1.42, Tn_count 0
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.12, err_os: 0.82
# 2 replica time: 1.40, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 1.44
# 3 replica time: 1.40, Tn_count 0
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.92
# 4 replica time: 1.41, Tn_count 0
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.79
# 5 replica time: 1.43, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.13, err_os: 0.97
# 6 replica time: 1.42, Tn_count 0
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.11, err_os: 1.34
# 7 replica time: 1.27, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.10, err_os: 1.39
# 8 replica time: 1.45, Tn_count 0
# proposal: 1.10e-03, start_point: 0.04, err_in: 0.11, err_os: 0.86
# 9 replica time: 1.43, Tn_count 0
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.83
# 10 replica time: 1.43, Tn_count 0
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.93
# 11 replica time: 1.44, Tn_count 0
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.12, err_os: 0.83
# 12 replica time: 1.43, Tn_count 0
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.88
# 13 replica time: 1.44, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.90
# 14 replica time: 1.39, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.04
# 15 replica time: 1.37, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.94
# 16 replica time: 1.44, Tn_count 0
# proposal: 1.05e-03, start_point: 0.02, err_in: 0.12, err_os: 1.74
# 17 replica time: 1.43, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.79
# 18 replica time: 1.42, Tn_count 0
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.11, err_os: 0.88
# 19 replica time: 1.36, Tn_count 0
# proposal: 7.02e-04, start_point: 0.02, err_in: 0.11, err_os: 0.85
# 20 replica time: 1.41, Tn_count 0
# proposal: 1.00e-03, start_point: 0.02, err_in: 0.09, err_os: 1.28
# 21 replica time: 1.37, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.13, err_os: 0.99
# 22 replica time: 1.41, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.13, err_os: 0.94
# 23 replica time: 1.44, Tn_count 0
# proposal: 8.52e-04, start_point: 0.02, err_in: 0.12, err_os: 1.00
# 24 replica time: 1.41, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.09, err_os: 0.89
# 25 replica time: 1.40, Tn_count 0
# proposal: 9.52e-04, start_point: 0.03, err_in: 0.11, err_os: 1.12
# 26 replica time: 1.36, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.10, err_os: 1.16
# 27 replica time: 1.42, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.67
# 28 replica time: 1.36, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.08, err_os: 0.71
# 29 replica time: 1.38, Tn_count 0
# proposal: 7.52e-04, start_point: 0.02, err_in: 0.12, err_os: 1.09
# 30 replica time: 1.40, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.07, err_os: 0.88
# 31 replica time: 1.39, Tn_count 0
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.09, err_os: 2.02
# 32 replica time: 1.41, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.02
# 33 replica time: 1.42, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.77
# 34 replica time: 1.40, Tn_count 0
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.11, err_os: 2.07
# 35 replica time: 1.37, Tn_count 0
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.10, err_os: 0.97
# 36 replica time: 1.38, Tn_count 0
# proposal: 1.00e-03, start_point: 0.03, err_in: 0.11, err_os: 1.51
# 37 replica time: 1.39, Tn_count 0
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.11, err_os: 2.00
# 38 replica time: 1.36, Tn_count 0
# proposal: 9.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.36
# 39 replica time: 1.55, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.69
# 40 replica time: 1.51, Tn_count 0
# proposal: 1.10e-03, start_point: 0.03, err_in: 0.12, err_os: 1.06
# 41 replica time: 1.35, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.71
# 42 replica time: 1.55, Tn_count 0
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.10, err_os: 1.15
# 43 replica time: 1.55, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.71
# 44 replica time: 1.57, Tn_count 0
# proposal: 8.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.85
# 45 replica time: 1.54, Tn_count 0
# proposal: 8.52e-04, start_point: 0.03, err_in: 0.11, err_os: 0.87
# 46 replica time: 1.51, Tn_count 0
# proposal: 1.15e-03, start_point: 0.03, err_in: 0.13, err_os: 2.06
# 47 replica time: 1.52, Tn_count 0
# proposal: 8.52e-04, start_point: 0.02, err_in: 0.10, err_os: 1.67
# 48 replica time: 1.53, Tn_count 0
# proposal: 1.05e-03, start_point: 0.03, err_in: 0.10, err_os: 1.10
# 49 replica time: 1.30, Tn_count 0
# proposal: 1.05e-03, start_point: 0.04, err_in: 0.10, err_os: 0.91
# train_size 50, IS error 0.10845050374481614, OS error 1.1036529454995483
# 0 replica time: 3.63, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.58
# 1 replica time: 3.68, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.69
# 2 replica time: 3.54, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.43
# 3 replica time: 3.76, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.63
# 4 replica time: 3.79, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.11, err_os: 0.48
# 5 replica time: 3.22, Tn_count 0
# proposal: 7.02e-04, start_point: 0.02, err_in: 0.10, err_os: 0.54
# 6 replica time: 3.36, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.77
# 7 replica time: 3.14, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.51
# 8 replica time: 3.21, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.47
# 9 replica time: 3.10, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 1.05
# 10 replica time: 3.07, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.09, err_os: 0.68
# 11 replica time: 3.09, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.51
# 12 replica time: 3.09, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.59
# 13 replica time: 3.13, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.81
# 14 replica time: 3.15, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.40
# 15 replica time: 3.21, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.09, err_os: 0.51
# 16 replica time: 3.30, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.89
# 17 replica time: 3.20, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.09, err_os: 0.92
# 18 replica time: 3.36, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.44
# 19 replica time: 3.29, Tn_count 0
# proposal: 6.51e-04, start_point: 0.02, err_in: 0.10, err_os: 1.06
# 20 replica time: 3.28, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.41
# 21 replica time: 3.21, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.12, err_os: 0.52
# 22 replica time: 3.33, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.08, err_os: 0.70
# 23 replica time: 3.15, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.60
# 24 replica time: 3.14, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.52
# 25 replica time: 3.21, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.47
# 26 replica time: 3.31, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.53
# 27 replica time: 3.47, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.52
# 28 replica time: 3.43, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.65
# 29 replica time: 4.55, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.51
# 30 replica time: 3.41, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.62
# 31 replica time: 3.13, Tn_count 0
# proposal: 6.51e-04, start_point: 0.02, err_in: 0.10, err_os: 0.53
# 32 replica time: 4.21, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.49
# 33 replica time: 3.32, Tn_count 0
# proposal: 8.02e-04, start_point: 0.02, err_in: 0.10, err_os: 1.35
# 34 replica time: 3.48, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.66
# 35 replica time: 3.90, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.59
# 36 replica time: 3.74, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.61
# 37 replica time: 3.25, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.12, err_os: 0.41
# 38 replica time: 3.26, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.47
# 39 replica time: 3.30, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.61
# 40 replica time: 3.24, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.10, err_os: 0.50
# 41 replica time: 3.22, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.11, err_os: 0.57
# 42 replica time: 3.31, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.47
# 43 replica time: 3.35, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.78
# 44 replica time: 3.35, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.64
# 45 replica time: 3.41, Tn_count 0
# proposal: 6.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.58
# 46 replica time: 3.46, Tn_count 0
# proposal: 6.01e-04, start_point: 0.02, err_in: 0.09, err_os: 0.93
# 47 replica time: 3.50, Tn_count 0
# proposal: 7.52e-04, start_point: 0.03, err_in: 0.10, err_os: 0.70
# 48 replica time: 3.53, Tn_count 0
# proposal: 7.02e-04, start_point: 0.03, err_in: 0.11, err_os: 0.61
# 49 replica time: 3.39, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.48
# train_size 100, IS error 0.10120474777865766, OS error 0.6199525481024538
# 0 replica time: 7.52, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.27
# 1 replica time: 7.36, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.34
# 2 replica time: 7.29, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 3 replica time: 8.59, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.30
# 4 replica time: 7.39, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.17
# 5 replica time: 7.48, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.31
# 6 replica time: 8.05, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.30
# 7 replica time: 7.83, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.25
# 8 replica time: 7.43, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.24
# 9 replica time: 7.61, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.27
# 10 replica time: 7.77, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.10, err_os: 0.25
# 11 replica time: 7.56, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 12 replica time: 7.53, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.26
# 13 replica time: 7.67, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.25
# 14 replica time: 7.43, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 15 replica time: 7.56, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.32
# 16 replica time: 7.57, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.24
# 17 replica time: 7.46, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.19
# 18 replica time: 7.91, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.22
# 19 replica time: 7.74, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 20 replica time: 7.58, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 21 replica time: 8.42, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 22 replica time: 7.65, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 23 replica time: 7.36, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.27
# 24 replica time: 8.44, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.29
# 25 replica time: 8.09, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.32
# 26 replica time: 7.54, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.27
# 27 replica time: 7.45, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 28 replica time: 7.49, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.10, err_os: 0.28
# 29 replica time: 7.37, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.27
# 30 replica time: 7.47, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 31 replica time: 7.79, Tn_count 0
# proposal: 6.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.30
# 32 replica time: 8.66, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.30
# 33 replica time: 7.70, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.23
# 34 replica time: 7.72, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.31
# 35 replica time: 8.79, Tn_count 0
# proposal: 5.01e-04, start_point: 0.02, err_in: 0.08, err_os: 0.30
# 36 replica time: 7.69, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.33
# 37 replica time: 7.72, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.24
# 38 replica time: 7.65, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.34
# 39 replica time: 7.45, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.21
# 40 replica time: 7.61, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.08, err_os: 0.31
# 41 replica time: 7.68, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.32
# 42 replica time: 7.85, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.32
# 43 replica time: 8.97, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.24
# 44 replica time: 8.03, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.29
# 45 replica time: 8.06, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.30
# 46 replica time: 7.11, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.08, err_os: 0.26
# 47 replica time: 8.32, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.22
# 48 replica time: 7.47, Tn_count 0
# proposal: 5.51e-04, start_point: 0.03, err_in: 0.09, err_os: 0.25
# 49 replica time: 10.26, Tn_count 0
# proposal: 5.01e-04, start_point: 0.03, err_in: 0.09, err_os: 0.21
# train_size 200, IS error 0.08694198611665876, OS error 0.27431750085983814

# %%
# sanity check of the computed posterior of knn prior
train_size = 50
# grid of marginal posterior of t
log_grid_pos_knn = dict_log_grid_pos_knn[train_size]
weight_pos = np.exp(log_grid_pos_knn - np.max(log_grid_pos_knn))
weight_pos = weight_pos/np.sum(weight_pos)

plt.figure(figsize=(8,3))
plt.subplot(121)
plt.plot(ls_grid_epsilon,weight_pos*(mcmc_time-burn_in),label = 'grid')
plt.title(f"train size {train_size}, grid vs mcmc")
plt.hist(dict_ls_epsilon_knn[train_size][burn_in:],bins = ls_grid_epsilon)
plt.legend()
plt.subplot(122)
plt.plot(dict_ls_epsilon_knn[train_size][burn_in:])
plt.title(f"train size {train_size}, mixing")
plt.show()

# %%
#kernel ridge cv
val_percent = 0.1
cv_means = []
cv_std = []
cv_test_means = []
cv_test_std = []
single_means = []
single_std = []
for train_size, replicas in zip(train_size_ls, replicas_ls):
    n_data = train_size + test_size
    ls_kernel_ridge,ls_kernel_ridge_test,ls_single = kernel_ridge_cv(train_size, replicas,val_percent,n_data,sigmasq_0,
                           n_grid, left_end,right_end,
                           data_loader=simulated_data_loader,data_loader_kwargs=data_loader_kwargs)
    cv_means.append(np.mean(ls_kernel_ridge))
    cv_std.append(np.std(ls_kernel_ridge))
    cv_test_means.append(np.mean(ls_kernel_ridge_test))
    cv_test_std.append(np.std(ls_kernel_ridge_test))
    single_means.append(np.mean(ls_single))
    single_std.append(np.std(ls_single))
    print(f"train_size {train_size}, IS error {np.mean(ls_kernel_ridge)}, OS error {np.mean(ls_kernel_ridge_test)}")
# Out:
# 0 replica time: 0.23
# 1 replica time: 0.20
# 2 replica time: 0.19
# 3 replica time: 0.18
# 4 replica time: 0.17
# 5 replica time: 0.16
# 6 replica time: 0.16
# 7 replica time: 0.15
# 8 replica time: 0.16
# 9 replica time: 0.15
# 10 replica time: 0.15
# 11 replica time: 0.16
# 12 replica time: 0.15
# 13 replica time: 0.16
# 14 replica time: 0.16
# 15 replica time: 0.15
# 16 replica time: 0.15
# 17 replica time: 0.15
# 18 replica time: 0.15
# 19 replica time: 0.15
# 20 replica time: 0.15
# 21 replica time: 0.15
# 22 replica time: 0.15
# 23 replica time: 0.15
# 24 replica time: 0.15
# 25 replica time: 0.15
# 26 replica time: 0.15
# 27 replica time: 0.15
# 28 replica time: 0.17
# 29 replica time: 0.18
# 30 replica time: 0.19
# 31 replica time: 0.17
# 32 replica time: 0.16
# 33 replica time: 0.16
# 34 replica time: 0.16
# 35 replica time: 0.20
# 36 replica time: 0.16
# 37 replica time: 0.16
# 38 replica time: 0.16
# 39 replica time: 0.16
# 40 replica time: 0.15
# 41 replica time: 0.16
# 42 replica time: 0.15
# 43 replica time: 0.16
# 44 replica time: 0.15
# 45 replica time: 0.15
# 46 replica time: 0.15
# 47 replica time: 0.15
# 48 replica time: 0.15
# 49 replica time: 0.15
# train_size 50, IS error 0.18460143412485688, OS error 1.3402969204680482
# 0 replica time: 0.35
# 1 replica time: 0.32
# 2 replica time: 0.32
# 3 replica time: 0.33
# 4 replica time: 0.33
# 5 replica time: 0.32
# 6 replica time: 0.31
# 7 replica time: 0.32
# 8 replica time: 0.37
# 9 replica time: 0.36
# 10 replica time: 0.32
# 11 replica time: 0.34
# 12 replica time: 0.34
# 13 replica time: 0.33
# 14 replica time: 0.32
# 15 replica time: 0.33
# 16 replica time: 0.32
# 17 replica time: 0.34
# 18 replica time: 0.33
# 19 replica time: 0.37
# 20 replica time: 0.32
# 21 replica time: 0.32
# 22 replica time: 0.34
# 23 replica time: 0.33
# 24 replica time: 0.33
# 25 replica time: 0.33
# 26 replica time: 0.34
# 27 replica time: 0.32
# 28 replica time: 0.33
# 29 replica time: 0.34
# 30 replica time: 0.33
# 31 replica time: 0.33
# 32 replica time: 0.32
# 33 replica time: 0.33
# 34 replica time: 0.33
# 35 replica time: 0.35
# 36 replica time: 0.34
# 37 replica time: 0.34
# 38 replica time: 0.33
# 39 replica time: 0.35
# 40 replica time: 0.33
# 41 replica time: 0.32
# 42 replica time: 0.34
# 43 replica time: 0.33
# 44 replica time: 0.33
# 45 replica time: 0.32
# 46 replica time: 0.33
# 47 replica time: 0.33
# 48 replica time: 0.34
# 49 replica time: 0.33
# train_size 100, IS error 0.1584297025395718, OS error 0.6832186126399129
# 0 replica time: 0.79
# 1 replica time: 0.83
# 2 replica time: 0.80
# 3 replica time: 0.81
# 4 replica time: 0.83
# 5 replica time: 0.79
# 6 replica time: 0.83
# 7 replica time: 0.83
# 8 replica time: 0.81
# 9 replica time: 0.83
# 10 replica time: 0.80
# 11 replica time: 0.84
# 12 replica time: 0.76
# 13 replica time: 0.66
# 14 replica time: 0.59
# 15 replica time: 0.60
# 16 replica time: 0.59
# 17 replica time: 0.60
# 18 replica time: 0.59
# 19 replica time: 0.58
# 20 replica time: 0.59
# 21 replica time: 0.59
# 22 replica time: 0.61
# 23 replica time: 0.59
# 24 replica time: 0.61
# 25 replica time: 0.61
# 26 replica time: 0.60
# 27 replica time: 0.67
# 28 replica time: 0.65
# 29 replica time: 0.78
# 30 replica time: 0.71
# 31 replica time: 0.65
# 32 replica time: 0.64
# 33 replica time: 0.62
# 34 replica time: 0.62
# 35 replica time: 0.60
# 36 replica time: 0.60
# 37 replica time: 0.62
# 38 replica time: 0.60
# 39 replica time: 0.62
# 40 replica time: 0.61
# 41 replica time: 0.64
# 42 replica time: 0.61
# 43 replica time: 0.63
# 44 replica time: 0.62
# 45 replica time: 0.65
# 46 replica time: 0.66
# 47 replica time: 0.67
# 48 replica time: 0.69
# 49 replica time: 0.68
# train_size 200, IS error 0.09988056615906107, OS error 0.3032160034796806

# %%
def format_stats(means, stds, precision=4):
    means_fmt = [f"{m:.{precision}f}" for m in means]
    stds_fmt  = [f"{s:.{precision}f}" for s in stds]
    return ", ".join([f"{m} ± {s}" for m, s in zip(means_fmt, stds_fmt)])


print("\n========== TEST PERFORMANCE ==========")
print(f"KNN-MCMC        : {format_stats(w_pos_knn_test_means, w_pos_knn_test_std)}")
print(f"Rescaled-Gamma  : {format_stats(w_pos_test_means,     w_pos_test_std)}")
print(f"KernelRidge-CV  : {format_stats(cv_test_means,        cv_test_std)}")

print("\n========== TRAIN PERFORMANCE ==========")
print(f"KNN-MCMC        : {format_stats(w_pos_knn_means, w_pos_knn_std)}")
print(f"Rescaled-Gamma  : {format_stats(w_pos_means,     w_pos_std)}")
print(f"KernelRidge-CV  : {format_stats(cv_means,        cv_std)}")
# Out:
# ========== TEST PERFORMANCE ==========
# KNN-MCMC        : 1.1037 ± 0.3829, 0.6200 ± 0.1876, 0.2743 ± 0.0375
# Rescaled-Gamma  : 1.1067 ± 0.3345, 0.6471 ± 0.2255, 0.2757 ± 0.0515
# KernelRidge-CV  : 1.3403 ± 0.4806, 0.6832 ± 0.2116, 0.3032 ± 0.0990
#
# ========== TRAIN PERFORMANCE ==========
# KNN-MCMC        : 0.1085 ± 0.0116, 0.1012 ± 0.0073, 0.0869 ± 0.0051
# Rescaled-Gamma  : 0.1110 ± 0.0131, 0.1022 ± 0.0087, 0.0864 ± 0.0050
# KernelRidge-CV  : 0.1846 ± 0.1199, 0.1584 ± 0.1162, 0.0999 ± 0.0163

# %%
#In-sample-error
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.errorbar(train_size_ls, cv_means, cv_std, linestyle='-', marker='*',label = "Kernel Ridge w/CV" ,capsize=5, capthick=2)
plt.errorbar(train_size_ls, w_pos_means, w_pos_std, linestyle='-', marker='*',label = "GP rescaled Gamma d=2",capsize=5, capthick=2)
plt.errorbar(train_size_ls, w_pos_knn_means, w_pos_knn_std, linestyle='-', marker='*',label = "GP EB (ours)",capsize=5, capthick=2)
plt.errorbar(train_size_ls, single_means, single_std, linestyle='-', marker='*',label = "Single point" ,capsize=5, capthick=2)
plt.xlabel('number of training data', fontsize = 15)
plt.grid()
plt.title(r'$||\hat{f}-f^*||_{n}$ on training data', fontsize = 18)
plt.xscale('log')
plt.yscale('log')
plt.ylim([0.015, 5])
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize=13)

#Out-of-sample error 
plt.subplot(122)
plt.errorbar(train_size_ls, cv_test_means, cv_test_std, linestyle='-', marker='*',label = "Kernel Ridge w/ CV" ,capsize=5, capthick=2)
plt.errorbar(train_size_ls, w_pos_test_means, w_pos_test_std, linestyle='-', marker='*',label = "GP rescaled Gamma d=2",capsize=5, capthick=2)
plt.errorbar(train_size_ls, w_pos_knn_test_means, w_pos_knn_test_std, linestyle='-', marker='*',label = "GP EB (ours)",capsize=5, capthick=2)
plt.xlabel('number of training data', fontsize = 15)
plt.grid()
plt.title(r'$||\hat{f}-f^*||_{2}$ on testing data', fontsize = 18)
plt.xscale('log')
plt.yscale('log')
plt.ylim([0.015, 5])
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 13)
plt.show()
